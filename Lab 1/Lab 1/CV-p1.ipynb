# %%
import cv2
from matplotlib import pyplot as plt

im1 = cv2.imread(r'Computervision_banner.webp')

cv2.imshow("Original Image", im1)
cv2.waitKey(0)
cv2.destroyAllWindows() 


im2 = cv2.cvtColor(im1, cv2.COLOR_BGR2RGB)
cv2.imshow("Converted Image", im2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)

threshold_value = 128  
_, binary_image = cv2.threshold(gray, threshold_value, 255, cv2.THRESH_BINARY)

cv2.imshow("Binary Image", binary_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray_image = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  
blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)
edges = cv2.Canny(gray_image, 100, 200) 

cv2.imshow("Filtered Image", edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
th, binary_image = cv2.threshold(blurred_image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)


print(th)
cv2.imshow("Filtered Image", binary_image) 
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 106.0

# %%
import cv2

cap = cv2.VideoCapture(0)

i = 0
while True:
    ret, frame = cap.read()
    
    if not ret or cv2.waitKey(1) & 0xFF == ord('q'):
        break
    img = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    thresh = 106
    _,img2= cv2.threshold(img,thresh,255,cv2.THRESH_BINARY)
    cv2.imshow("video", img2)

    cv2.waitKey(1)
    
    i += 1

cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(r'C:\Users\ELmoor\Desktop\C-Vision\Lab 1\object detection\crossing-shorts-street-pedestrian-nyc.mp4')

ret, frame = cap.read()

fps = cap.get(cv2.CAP_PROP_FPS)
delay = int((1000 / fps))  
delay
# Out:
# 33
